# %% [markdown]
# DATASCI 151 Group Project
#
#
# Student ID Number: 2677374 (Elsa)

# %%
import pandas as pd

# %%
driver_standings = pd.read_csv('f1_data/driver_standings.csv')
display(driver_standings)

drivers = pd.read_csv('f1_data/drivers.csv')
display(drivers)

races = pd.read_csv('f1_data/races.csv')
display(races)

results = races = pd.read_csv('f1_data/results.csv')
display(results)
# Out:
#        driverStandingsId  raceId  driverId  points  position positionText  \
# 0                      1      18         1    10.0         1            1
# 1                      2      18         2     8.0         2            2
# 2                      3      18         3     6.0         3            3
# 3                      4      18         4     5.0         4            4
# 4                      5      18         5     4.0         5            5
# ...                  ...     ...       ...     ...       ...          ...
# 33681              71559    1086       807     0.0        21           21
# 33682              71560    1086       815   173.0         3            3
# 33683              71561    1086       830   258.0         1            1
# 33684              71562    1086       842    16.0        13           13
# 33685              71563    1086        20    16.0        14           14
#
#        wins
# 0         1
# 1         0
# 2         0
# 3         0
# ...
